# %%
import lancedb

db = lancedb.connect(uri="../knowledge_base")
diary = db['diary']

df = diary.to_pandas()

# %%
df['weekday'].value_counts()
# Out:
# weekday
# Torsdag    9
# Fredag     9
# Lördag     9
# Söndag     9
# Måndag     9
# Tisdag     9
# Onsdag     8
# Name: count, dtype: int64
