# %%
import lancedb

db = lancedb.connect(uri="../knowledge_base")
diary = db['diary']

#db["news"].to_pandas()

db["diary"].head()
# Out:
# pyarrow.Table
# activity: string not null
# feelings: string not null
# mood: string not null
# keywords: string not null
# date: timestamp[us] not null
# weekday: string not null
# content: string not null
# embedding: fixed_size_list<item: float>[3072]
#   child 0, item: float
# ----
# activity: [["Långkok av höstgryta hela eftermiddagen","Vaknade med feber och ont i halsen","Sjukskriven och sov bort halva dagen","Började känna mig bättre åt soppa","Tillbaka på jobbet till inkorgen från helvetet"]]
# feelings: [["Hemtrevligt och gott","Sänkt och ynklig","Utmattad","På bättringsvägen","Stressad direkt"]]
# mood: [["Positivt","Negativt","Negativt","Positivt","Negativt"]]
# keywords: [["Mat, Matlagning, Höst","Sjukdom, Hälsa, Feber","Sjukdom, Sömn, Vila","Sjukdom, Mat, Återhämtning","Jobb, Stress, Vardag"]]
# date: [[2025-11-01 00:00:00.000000,2025-11-02 00:00:00.000000,2025-11-03 00:00:00.000000,2025-11-04 00:00:00.000000,2025-11-05 00:00:00.000000]]
# weekday: [["Lördag","Söndag","Måndag","Tisdag","Onsdag"]]
# content: [["Veckodag: Lördag. Aktivitet: Långkok av höstgryta hela eftermiddagen. Mående: Hemtrevligt och  (... 57 chars omitted)","Veckodag: Söndag. Aktivitet: Vaknade med feber och ont i halsen. Mående: Sänkt och ynklig. Hum� (... 47 chars omitted)","Veckodag: Måndag. Aktivitet: Sjukskriven och sov bort halva dagen. Mående: Utmattad. Humör: Neg (... 38 chars omitted)","Veckodag: Tisdag. Aktivitet: Började känna mig bättre åt soppa. Mående: På bättringsvägen. (... 58 chars omitted)","Veckodag: Onsdag. Aktivitet: Tillbaka på jobbet till inkorgen från helvetet. Mående: Stressad d (... 56 chars omitted)"]]
# embedding: [[[0.014175165,0.0008193937,-0.005386563,0.0045775413,0.0324715,...,0.023662154,0.006472173,-0.019098442,-0.0065344055,-0.00022256738],[0.010047093,0.037619844,0.0011464322,-0.009534685,0.026230112,...,0.023051884,-0.005808374,-0.019263955,0.009742242,-0.009904397],[0.009076915,0.019942904,0.002765828,-0.016180588,0.020087607,...,0.026494069,-0.0006577475,-0.022074005,0.0085507175,-0.012799766],[0.017921446,0.0049370467,-0.0044561434,-0.0003064031,0.00025256092,...,0.016772812,-0.0013397838,-0.017533954,-0.0023387831,-0.0025965336],[0.015089493,-0.0036627948,-0.0034669905,-0.020291775,0.012466795,...,0.0054322174,0.004526848,-0.020837871,0.012797327,-0.010893176]]]

# %%
worst_day = df.query("mood == 'negativt'")['weekday'].value_counts().idxmax()
worst_day
# Out:
# 'Torsdag'

# %%
df
# Out:
#                                          activity                    feelings  \
# 0   Började skissa på arkitekturen för AI-agenten  Entusiastisk och fokuserad
# 1              Lång dag på jobbet med många möten          Trött och dränerad
# 2   Långpromenad i skogen och lyssnade på podcast          Lugn och harmonisk
# 3     Felsökte Docker-containers hela förmiddagen    Frustrerad och irriterad
# 4              Tog en vilodag och kollade på film                  Avslappnad
# ..                                            ...                         ...
# 63                   sitter med mina två kompisar        jättekul, det är bra
# 64                             kompisar var dumma                      ledsen
# 65              Tänkte på ord och försökte förstå                    Tankfull
# 66   Något är på gång och jag hoppas det fungerar                        glad
# 67                        Kört barnen till skolan                  avslappnad
#
#         mood       date  weekday  \
# 0   positivt 2025-11-20  Torsdag
# 1   negativt 2025-11-21   Fredag
# 2   positivt 2025-11-22   Lördag
# 3   negativt 2025-11-23   Söndag
# 4   positivt 2025-11-24   Måndag
# ..       ...        ...      ...
# 63  positivt 2026-01-22  Torsdag
# 64  negativt 2026-01-22  Torsdag
# 65  positivt 2026-01-22  Torsdag
# 66  positivt 2026-01-22  Torsdag
# 67  positivt 2026-01-26   Måndag
#
#                                               content  \
# 0   Veckodag: Torsdag. Aktivitet: Började skissa p...
# 1   Veckodag: Fredag. Aktivitet: Lång dag på jobbe...
# 2   Veckodag: Lördag. Aktivitet: Långpromenad i sk...
# 3   Veckodag: Söndag. Aktivitet: Felsökte Docker-c...
# 4   Veckodag: Måndag. Aktivitet: Tog en vilodag oc...
# ..                                                ...
# 63  Veckodag: Torsdag. Aktivitet: sitter med mina ...
# 64  Veckodag: Torsdag. Aktivitet: kompisar var dum...
# 65  Veckodag: Torsdag. Aktivitet: Tänkte på ord oc...
# 66  Veckodag: Torsdag. Aktivitet: Något är på gång...
# 67  Veckodag: Måndag. Aktivitet: Kört barnen till ...
#
#                                             embedding
# 0   [-0.013487314, 0.0062653343, -0.013992988, -0....
# 1   [-0.014956831, -0.0006175916, -0.024765158, -0...
# 2   [0.003948058, -0.0067385472, -0.011930484, -0....
# 3   [-0.0042320252, -0.005770693, -0.025876129, -0...
# 4   [-0.016784325, -0.0029586395, -0.017142043, -0...
# ..                                                ...
# 63  [-0.0035514943, -0.0065731797, -0.022200089, -...
# 64  [0.00033151975, -0.0044665923, -0.023261925, -...
# 65  [-0.011616978, -0.005292408, -0.0066994354, -0...
# 66  [-0.011907473, -0.012639426, -0.0037151128, -0...
# 67  [-0.015234708, -0.0016863095, -0.021966897, -0...
#
# [68 rows x 7 columns]

# %%
df['weekday'].value_counts()
# Out:
# weekday
# Torsdag    13
# Måndag     10
# Fredag      9
# Lördag      9
# Söndag      9
# Tisdag      9
# Onsdag      9
# Name: count, dtype: int64

# %%
df[df['mood'] == 'positivt']['weekday'].value_counts()
# Out:
# weekday
# Lördag     9
# Torsdag    7
# Måndag     7
# Tisdag     6
# Söndag     6
# Onsdag     6
# Fredag     5
# Name: count, dtype: int64

# %%
df['mood'].value_counts()
# Out:
# mood
# positivt    46
# negativt    22
# Name: count, dtype: int64

# %%
df['feelings'].unique()
# Out:
# array(['Entusiastisk och fokuserad', 'Trött och dränerad',
#        'Lugn och harmonisk', 'Frustrerad och irriterad', 'Avslappnad',
#        'Stolt och nöjd', 'Seg och ofokuserad',
#        'Fysiskt trött men mentalt pigg', 'Glad och social',
#        'Uttråkad men nöjd efteråt', 'Inspirerad men sömnig',
#        'Mysigt och familjärt', 'Orolig och stressad', 'Lättad och glad',
#        'Hängig och låg', 'Uttråkad', 'Piggare', 'Lite nedstämd',
#        'Produktiv och stark', 'Nyfiken och exalterad', 'Melankolisk',
#        'Energifylld', 'Mätt och belåten', 'Utsövd', 'Stressad och varm',
#        'Nördigt glad', 'Arg och ledsen', 'Lättad', 'Fokuserad stress',
#        'Euforisk och fri', 'Avkopplad', 'Kreativ', 'Nostalgisk och glad',
#        'Förväntansfull', 'Glad men trött på slutet', 'Lat och nöjd',
#        'Irriterad på folk', 'Fascinerad', 'Utmattad men stolt',
#        'Intellektuellt stimulerad', 'Stressad över detaljer',
#        'Festlig och hoppfull', 'Seg och bakis', 'Vemodig', 'Imponerad',
#        'Kall men uppfriskad', 'Omotiverad', 'Nöjd problemlösare',
#        'Chockad över tempot', 'Skärrad och ångestfylld', 'Kärleksfull',
#        'Organiserad', 'Deppig över vintern', 'I "zonen"', 'Uppskattad',
#        'Smärtpåverkad och sur', 'Tävlingsinriktad och glad',
#        'Konstnärlig', 'Taggad och redo', 'Mycket exalterad och positiv',
#        'jättekul, det är bra', 'ledsen', 'Tankfull', 'glad', 'avslappnad'],
#       dtype=object)

# %%
# Filtrera rader -> Välj kolumn -> Hämta unika
unique = df[df['mood'] == "negativt"]['feelings'].unique()
unique
# Out:
# array(['Trött och dränerad', 'Frustrerad och irriterad',
#        'Seg och ofokuserad', 'Orolig och stressad', 'Hängig och låg',
#        'Uttråkad', 'Lite nedstämd', 'Melankolisk', 'Stressad och varm',
#        'Arg och ledsen', 'Fokuserad stress', 'Irriterad på folk',
#        'Stressad över detaljer', 'Seg och bakis', 'Vemodig', 'Omotiverad',
#        'Chockad över tempot', 'Skärrad och ångestfylld',
#        'Deppig över vintern', 'Smärtpåverkad och sur', 'ledsen'],
#       dtype=object)

# %% [markdown]
# ## Eller med query (SQL)

# %%
unika = df.query("mood == 'negativt'")['feelings'].unique()
unika
# Out:
# array(['Trött och dränerad', 'Frustrerad och irriterad',
#        'Seg och ofokuserad', 'Orolig och stressad', 'Hängig och låg',
#        'Uttråkad', 'Lite nedstämd', 'Melankolisk', 'Stressad och varm',
#        'Arg och ledsen', 'Fokuserad stress', 'Irriterad på folk',
#        'Stressad över detaljer', 'Seg och bakis', 'Vemodig', 'Omotiverad',
#        'Chockad över tempot', 'Skärrad och ångestfylld',
#        'Deppig över vintern', 'Smärtpåverkad och sur', 'ledsen'],
#       dtype=object)

# %%
# Gruppera på mood, och ta unika värden från feelings
resultat = df[df['mood'] == "negativt"].groupby('mood')['feelings'].unique()
resultat.reset_index()
# Out:
#        mood                                           feelings
# 0  negativt  [Trött och dränerad, Frustrerad och irriterad,...

# %%
articles = db['science']

df_art = articles.to_pandas()

df_art.tail(10)
# Out:
#                title                                            content  \
# 632  the-perma-model  eighbours for example – need \nsupport and com...
# 633  the-perma-model  es goals and achieving them, we improve our se...
# 634  the-perma-model  ing to go to the gym every single day’ \n‘I’m ...
# 635  the-perma-model  ogress. \n Assignable – specify who will do i...
# 636  the-perma-model   help with keeping a positive mental state of ...
# 637  the-perma-model   have a unique chance to help others in need g...
# 638  the-perma-model  u are actively equipping yourself and \nby ass...
# 639  the-perma-model  helle Walklett, Yvonne Smith, \nDawn Kirby, Ka...
# 640  the-perma-model   are giving care workers the tools to manage t...
# 641  the-perma-model  ionship support. \nwww.relate.org.uk \n CALM ...
#
#                                              embedding
# 632  [0.0014843082, 0.012439547, 0.001990641, -0.05...
# 633  [-0.0134765655, 0.018394439, 0.013110178, -0.0...
# 634  [-0.012684507, 0.0059569334, 0.018914463, -0.0...
# 635  [-0.0051912596, -0.0023140223, 0.0056100655, -...
# 636  [0.007203521, 0.012537478, -0.00021645243, -0....
# 637  [0.00031343204, 0.026645053, 0.014717811, -0.0...
# 638  [-0.010956416, 0.004518018, 0.0061883205, -0.0...
# 639  [-0.007184507, 0.003023898, 0.0064071813, -0.0...
# 640  [0.00052370183, -0.0006993404, -0.0016344001, ...
# 641  [-0.02041697, -0.010235458, -0.02409271, -0.04...
