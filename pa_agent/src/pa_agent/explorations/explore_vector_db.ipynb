# %%
import lancedb

db = lancedb.connect(uri="../knowledge_base")
diary = db['diary']

df = diary.to_pandas()

# %%
df
# Out:
#                                          activity  \
# 0   Började skissa på arkitekturen för AI-agenten
# 1              Lång dag på jobbet med många möten
# 2   Långpromenad i skogen och lyssnade på podcast
# 3     Felsökte Docker-containers hela förmiddagen
# 4              Tog en vilodag och kollade på film
# ..                                            ...
# 62                    Börjat ett nytt grupprojekt
# 63                   sitter med mina två kompisar
# 64                             kompisar var dumma
# 65              Tänkte på ord och försökte förstå
# 66   Något är på gång och jag hoppas det fungerar
#
#                             mood       date  weekday  \
# 0     Entusiastisk och fokuserad 2025-11-20  Torsdag
# 1             Trött och dränerad 2025-11-21   Fredag
# 2             Lugn och harmonisk 2025-11-22   Lördag
# 3       Frustrerad och irriterad 2025-11-23   Söndag
# 4                     Avslappnad 2025-11-24   Måndag
# ...

# %%
df['weekday'].value_counts()
# Out:
# weekday
# Torsdag    13
# Fredag      9
# Lördag      9
# Söndag      9
# Måndag      9
# Tisdag      9
# Onsdag      9
# Name: count, dtype: int64

# %%
articles = db['science']

df = articles.to_pandas()

df.head()
# Out:
#    title                                            content  \
# 0  whr25  World Happiness Report 2025March 2025\n2025\n\...
# 1  whr25  . . . . .3 \nHelliwell, Layard, Sachs, De Neve...
# 2  whr25  written by a group of independent experts acti...
# 3  whr25  hant of  \nVenice, caring is \n“twice-blessed”...
# 4  whr25   dropped in the street by researchers, the \np...
#
#                                            embedding
# 0  [-0.009563816, 0.01214505, -0.009603708, -0.05...
# 1  [-0.004129565, -0.00226069, -0.013577373, -0.0...
# 2  [0.00097005826, 0.012143829, -0.017596405, -0....
# 3  [-0.0030463033, 0.008970676, -0.0074999346, -0...
# 4  [-0.0057818657, -0.016864916, 0.0004100338, -0...
